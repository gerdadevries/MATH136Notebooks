# %% [markdown]
# <font color=blue>NOTE: Videos and graphs do not display immediately on all devices.  If this is the case for you, click the "Cell" menu option, and select "Run All".  If you still do not see the videos/graphs, try a different browser.  If that also does not work, please let your instructor know by email.</font>
#
# # Systems of Differential Equations
#
# In this notebook, we introduce the concept of a <i>system of coupled differential equations</i>.  Almost any phenomenon observed in the real world results from the interactions of multiple factors.  For example, in a predator-prey system (wolves and rabbits, ladybugs and aphids, etc), two species interact.  A decline in the prey population affects the predator population and vice versa.
#
# We limit our attention to systems of two autonomous differential equations and the visualization of the solutions in the phase plane.
#
# ### 1. Autonomous Differential Equations
#
# Autonomous differential equations are those that involve the derivative of an unknown function (the dependent variable) and the function itself, but not the independent variable.
#
# For example, the World's Most Important Differential Equation,
# $$\frac{dx}{dt} = \lambda x,$$
# and the Logistic Equation,
# $$\frac{dN}{dt} = r N \left( 1 - \frac{N}{K} \right),$$
# both are autonomous differential equations, but
# $$\frac{dy}{dt} = 1 + \sin(t) - y$$
# is not.
#
# ### 2. Parametric curves
#
# We make a brief detour to introduce the concept of a parametric curve.  We will see later that solutions of systems of autonomous differential equations can be represented as parametric curves.
#
# Suppose that $x$ and $y$ are both functions of time $t$, that is, they are defined by the equations
# $$x = f(t) \ \ \text{and} \ \ y = g(t).$$
#
# Each value of $t$ determines a point $(x,y)$ that we can plot in the coordinate plane.  As $t$ varies, the point $(x,y) = (f(t), g(t))$ also varies and traces a curve in the coordinate plane.  Such curve is called a <i>parametric curve</i>.  The equations $x = f(t)$ and $y = g(t)$ are called <i>parametric equations</i>.
#
# For example, suppose we have parametric equations $x = t^2 - 2t$ and $y = t+1$.  The table shown below shows the values of $x$ and $y$ for various values of $t$, and the figure shown below shows the resulting parametric curve in the coordinate plane.  Note that the direction of the movement as $t$ increases is indicated with arrows.
#
# ![07p460Combined.jpg](attachment:07p460Combined.jpg)
#
# <font size=0>Credit: Biocalculus: Calculus for the Life Sciences, J. Stewart and T. Day, Cengage Learning, 2015.</font>
#
# ### 3. A System of Two Autonomous Differential Equations
#
# Consider a system of two autonomous differential equations
# $$\begin{eqnarray}
# \frac{dx}{dt} & = f(x,y) \\
# \frac{dy}{dt} & = g(x,y).
# \end{eqnarray}$$
#
# A solution of this system of differential equations is a pair of functions $x(t)$ and $y(t)$ that <i>simultaneously</i> satisfy the two differential equations.
#
# To visualize the solution, it is helpful to show both of the following:
#
# 1. The graph of $x(t)$ versus $t$ and the graph of $y(t)$ versus $t$.
#
#
# 2. The graph of $y(t)$ vs $x(t)$, that is, the parametric curve in the $(x,y)$ plane.  In the context of a system of differential equations, the $(x,y)$ plane is also known as the <i>phase plane</i>.
#
# ### 4. The Love Affair of Romeo and Juliet
#
# By way of example, consider the relationship between two lovers, Romeo and Juliet. It is reasonable to expect that their relationship will be dynamic. That is, we expect Romeo and Juliet's feelings for each other to change over time.  Moreover, Romeo and Juliet influence each other's feelings.
#
# The love affair of Romeo and Juliet is explored via a model of two linear autonomous differential equations in an online module (developed by Dr. Gerda de Vries, University of Alberta, and undergraduate student Cole Zmurchok).  Take a look!
#
# 1. Open the module, which can be found at the following link: https://www.math.ualberta.ca/~devries/crystal/ContinuousRJ/index.html
#
# > You will need a browser with JavaScript installed.
#
# 2. Do not worry about the references to linear algebra; we will skip the linear algebra components of the module (readers familiar with linear algrebra may wish to work throug the linear algebra components of the module for an introduction to the intimate connections between differential equations and linear algebra).
#
#
# 3. Work through Section 2 (Introduction), Section 3 (Experimentation), and Section 4 (Six Case Studies).  Note that for Section 4, it is possible to run the simulator independently via the following link:https://www.math.ualberta.ca/~devries/crystal/ContinuousRJ/applets/continuous.swf
#
#
# 4. As you work through these sections, ask yourself the following questions:
#
#     - What makes the two differential equations a system of <i>coupled</i> differential equations?
#
#     - How are the graphs of $R(t)$ versus $t$ and $J(t)$ versus $t$ related to the solutions in the $(R,J)$ phase plane?
#
#     - Note that the solution trajectories in the phase plane are missing the arrows indicating the direction of increasing $t$.  For each of the six case studies, can you determine the direction of the arrows?
#
# ### 5. Summary
#
# <b>Parametric Equations and Parametric Curves</b>
#
# - <i>Parametric equations</i> represent variables that depend on a parameter (or multiple parameters).  In the context of differential equations in MATH 136, parametric equations depend on only one parameter, and the parameter most often is time $t$.
#
#
# - A <i>parametric curve</i> is a curve that is defined parametrically; it is the curve traced out in variable space as the parameter is varied.
#
# <b>Autonomous Differential Equations</b>
#
# - <i>Autonomous<i> differential equations are those that involve the derivative of an unknown function (the dependent variable) and the function itself, but not the independent variable.
#
# <b>Systems of (Autonomous) Differential Equations</b>
#
# - For the following system of two autonomous differential equations:
# $$\begin{eqnarray}
# \frac{dx}{dt} & = f(x,y) \\
# \frac{dy}{dt} & = g(x,y)
# \end{eqnarray}$$
#
#     - A <i>solution</i> is the pair of functions $x(t)$ and $y(t)$ that simultaneously satisfy the differential equations.
#
#     - The <i>phase plane</i> is the $(x,y)$ plane; the phase plane is used to represent solutions of the system of differential equations as parametric curves.
#
# ### 6. Further Study
#
# Please refer to Section 7.5 in the textbook for additional treatment of this topic.
#
# ### 7. Don't Forget
#
# Don't forget to return to eClass to complete the pre-class quiz.
