# %% [markdown]
# <font color=blue>NOTE: Videos and graphs do not display immediately on all devices.  If this is the case for you, click the "Cell" menu option, and select "Run All".  If you still do not see the videos/graphs, try a different browser.  If that also does not work, please let your instructor know by email.</font>
#
# # Exponential and Normal Random Variables
#
# In this notebook, we turn out attention to two commonly-used continuous random variables.  We already learned about <i>uniform</i> random variables in class.  Two additional random variables that occur frequently are <i>exponential</i> and <i>normal</i> random variables.
#
# ### 1. Exponential Random Variables
#
# Exponential random variables are used in situations involving a waiting time.  Examples in our lifes include waiting for a service representative to answer our phone call, or waiting for the LRT to arrive at University Station.  Biological examples include a predator waiting for a prey to arrive, or waiting for a new drug therapy to be developed.
#
# In general, an exponential random variable $T$ with positive parameter $c$ takes on values from the set $[0, \infty)$ and has probability density function
# $$f(t) = \begin{cases}
# c e^{-c t} & \text{for } t \ge 0 \\
# 0 & \text{for } t < 0.
# \end{cases}$$
#
# It is a straightforward exercise (using integration by parts; left to the reader) to show that the expected value or mean of $T$ is
# $$E[T] = \mu = \int_{-\infty}^{\infty} t f(t) \ dt = c \int_0^{\infty} t e^{-ct} \ dt = \frac{1}{c}.$$
#
# We therefore can rewrite the probability density function in terms of the mean $\mu$, as follows:
# $$f(t) = \begin{cases}
# \frac{1}{\mu} e^{-\frac{1}{\mu} t} & \text{for } t \ge 0 \\
# 0 & \text{for } t < 0.
# \end{cases}$$
#
# The graphs of the probability density functions for two exponential random variables are shown below, for $\mu = 2$ and $\mu = 1/2$.  Note that the larger the value of $\mu$, the slower the exponential decay to zero.
#
# ![exponential.jpg](attachment:exponential.jpg)
#
# <font size=0>Credit: Generated by WolframAlpha using the command `plot 1/2 e^(-1/2 t) and 2 e^(-2t), t=0..10, y=0..2`.</font>
#
# In the following video, we work through an example using the exponential random variable.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('LHd4jVK3fP8')

# %% [markdown]
# ### 2. Normal Random Variables
#
# Normal random variables are used in situations where many independent factors influence an outcome.  Typical applications are to describe the characteristics of an individual or organism (such as the height of a MATH 136 student, determined by a combination of genetic, developmental, and environmental factors), tests results (such as MCAT scores), or measurement errors.
#
# A normal random variable $X$ with mean $\mu$ and standard deviation $\sigma$ has probability density function
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{ -\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2}.$$
#
# The graphs of the probability density function for three normal random variables with the same mean $\mu =$ 5 but different standard deviations $\sigma$ ($\sigma =$ 1, 5, and 10) are shown below.  Note that the probability density functions are symmetric about the mean $\mu$.  Further, the smaller the value of the standard deviation $\sigma$, the more tightly clustered the values of $X$ are about the mean (the larger the value of the standard deviation $\sigma$, the larger the spread of the values of $X$).
#
# ![normal.jpg](attachment:normal.jpg)
#
# <font size=0>Credit: Generated by WolframAlpha using the command `plot { 1\(1 sqrt(2 pi)) e^( -1/2 ((x-5)/1)^2 ), 1\(5 sqrt(2 pi)) e^( -1/2 ((x-5)/5)^2 ), 1\(10 sqrt(2 pi)) e^( -1/2 ((x-5)/10)^2 ) }, x=-10..20, y=0..0.45`.</font>
#
# In the following video, we work through an example using the normal random variable.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('nEyr3p_hxJg')

# %% [markdown]
# ### 3. Summary
#
# <b>Exponential Random Variables</b>
#
# - An exponential random variable $T$ with mean $\mu$ has probability density function
# $$f(t) = \begin{cases}
# \frac{1}{\mu} e^{-\frac{1}{\mu} t} & \text{for } t \ge 0 \\
# 0 & \text{for } t < 0.
# \end{cases}$$
#
# <b>Normal Random Variables</b>
#
# - A normal random variable $X$ with mean $\mu$ and standard deviation $\sigma$ has probability density function
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{ -\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2}.$$
#
# ### 4. Further Study
#
# Please refer to Section 12.5 in the textbook for additional treatment of this topic.  Note: If you have a hardcopy of the textbook, there is no Chapter 12.  The eBook that you have access to through WebAssign does have Chapter 12.
#
# ### 5. Don't Forget
#
# Don't forget to return to eClass to complete the pre-class quiz.
